# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')

from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hashe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\hashe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
data = [
    "This is the first document",
    "This is the second document",
    "This is the third document",
    "This is the fourth document"
]

# %%
tagged_data = [
    TaggedDocument(
        words=word_tokenize(doc.lower()),
        tags=[str(i)]
    )
    for i, doc in enumerate(data)
]

# %%
model = Doc2Vec(
    vector_size=20,
    min_count=1,
    epochs=50
)

model.build_vocab(tagged_data)

model.train(
    tagged_data,
    total_examples=model.corpus_count,
    epochs=model.epochs
)

print("Doc2Vec model trained successfully!")
# Out:
# Doc2Vec model trained successfully!

# %%
document_vectors = [
    model.infer_vector(word_tokenize(doc.lower()))
    for doc in data
]

print("Document vectors generated successfully!")
# Out:
# Document vectors generated successfully!

# %%
document_vectors = [
    model.infer_vector(word_tokenize(doc.lower()))
    for doc in data
]

for i, doc in enumerate(data):
    print("Document", i + 1, ":", doc)
    print("Vector:", document_vectors[i])
    print()
# Out:
# Document 1 : This is the first document
# Vector: [ 0.0099225   0.01276824  0.00241097  0.00166728  0.00143363 -0.01207861
#   0.00228322 -0.00837081  0.00948451 -0.01541152  0.02068616  0.02169665
#  -0.02426954  0.01432906  0.01033372 -0.00530085 -0.02388333 -0.01325967
#  -0.01414888  0.00252712]
#
# Document 2 : This is the second document
# Vector: [-0.00734359 -0.02441473 -0.00187188 -0.01932409 -0.00876971 -0.00735832
#  -0.0234604   0.0032674   0.01755535  0.02056784  0.00834078 -0.00011981
#  -0.02588189  0.0014732  -0.01712428 -0.02426769  0.0011716  -0.00252051
#  -0.02287931 -0.01619967]
#
# Document 3 : This is the third document
# Vector: [ 0.01884033 -0.00736401 -0.016978   -0.01998187 -0.00823024  0.00524206
#  -0.00863244  0.01849267  0.0168492  -0.00631968 -0.02349839 -0.00477183
#   0.01699105 -0.00774437 -0.01502159  0.01981892  0.00236793  0.00406934
#  -0.02672505 -0.01243305]
#
# Document 4 : This is the fourth document
# Vector: [ 0.00333824  0.00915892  0.00942521 -0.01001393 -0.01671367 -0.00914655
#   0.00998653 -0.00687179 -0.0229031  -0.00386008 -0.01027268 -0.01730943
#  -0.01295983 -0.00300732  0.00833858 -0.01883187 -0.01061699  0.00411472
#   0.01880666 -0.00836919]

# %%
print("Vector size:", model.vector_size)

for i, vector in enumerate(document_vectors):
    print(f"Document {i + 1} vector length:", len(vector))
# Out:
# Vector size: 20
# Document 1 vector length: 20
# Document 2 vector length: 20
# Document 3 vector length: 20
# Document 4 vector length: 20
